# %% [markdown]
# # 1. About the Dataset
#
# This dataset contains the 1,000 most popular movies on IMDb between 2006 and 2016. Each row represents a single movie. The dataset consists of variables that include movie attributes such as rank, title, genre, description, director, actors, year, runtime, rating, votes, revenue, and metascore.
#
# <table style='text-align: left; margin-left: 0;'>
#   <tr>
#     <th>Column Name</th>
#     <th>Description</th>
#   </tr>
#   <tr>
#     <td><strong>Rank</strong></td>
#     <td>Order number within the dataset</td>
#   </tr>
#   <tr>
#     <td><strong>Title</strong></td>
#     <td>Movie title</td>
#   </tr>
#   <tr>
#     <td><strong>Genre</strong></td>
#     <td>Movie genre or genres</td>
#   </tr>
#   <tr>
#     <td><strong>Description</strong></td>
#     <td>Short description of the movie</td>
#   </tr>
#   <tr>
#     <td><strong>Director</strong></td>
#     <td>Director of the movie</td>
#   </tr>
#   <tr>
#     <td><strong>Actors</strong></td>
#     <td>Main actors appearing in the movie</td>
#   </tr>
#   <tr>
#     <td><strong>Year</strong></td>
#     <td>Release year of the movie</td>
#   </tr>
#   <tr>
#     <td><strong>Runtime</strong></td>
#     <td>Movie duration</td>
#   </tr>
#   <tr>
#     <td><strong>Rating</strong></td>
#     <td>IMDb user rating</td>
#   </tr>
#   <tr>
#     <td><strong>Votes</strong></td>
#     <td>Total number of votes received by the movie</td>
#   </tr>
#   <tr>
#     <td><strong>Revenue</strong></td>
#     <td>Box office revenue of the movie</td>
#   </tr>
#   <tr>
#     <td><strong>Metascore</strong></td>
#     <td>Critic-based metascore rating</td>
#   </tr>
# </table>

# %% [markdown]
# # 2. Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
pd.set_option('display.max_columns', None)  
plt.rcParams['figure.figsize'] = (10, 6)  
plt.style.use('ggplot')  
warnings.filterwarnings('ignore')

# %% [markdown]
# # 3. Loading the Dataset

# %%
df = pd.read_csv('../data/imdb_raw.csv')

df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df_copy = df.copy()

# %% [markdown]
# # 4. Dataset Overview

# %%
df.sample()
# Out:
#      Rank           Title               Genre  \
# 762   763  Eye in the Sky  Drama,Thriller,War
#
#                                            Description    Director  \
# 762  Col. Katherine Powell, a military officer in c...  Gavin Hood
#
#                                                 Actors  Year  \
# 762  Helen Mirren, Aaron Paul, Alan Rickman, Barkha...  2015
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 762                102     7.3  57826                18.7       73.0

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %% [markdown]
# <div style='background-color: #ffebee; border-left: 5px solid #f44336; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #c62828;'>🧾 Findings</h3>
#   <ul>
#     <li>There is a column in the dataset that is unnecessary for the analysis.</li>
#     <li>There are non-standard naming conventions in the column names.</li>
#     <li>The dataset contains missing values.</li>
#   </ul>
# </div>
#
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Decision</h3>
#   <ul>
#     <li><strong>Rank</strong> column will be removed from the dataset, and after the necessary adjustments, exploratory data analysis will be performed through column-based analysis.</li>
#   </ul>
# </div>

# %% [markdown]
# # 5. Data Cleaning and Preprocessing

# %%
df = df.drop(columns='Rank')

df
# Out:
#                        Title                     Genre  \
# 0    Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1                 Prometheus  Adventure,Mystery,Sci-Fi
# 2                      Split           Horror,Thriller
# 3                       Sing   Animation,Comedy,Family
# 4              Suicide Squad  Action,Adventure,Fantasy
# ..                       ...                       ...
# 995     Secret in Their Eyes       Crime,Drama,Mystery
# 996          Hostel: Part II                    Horror
# 997   Step Up 2: The Streets       Drama,Music,Romance
# 998             Search Party          Adventure,Comedy
# 999               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.columns = ['title', 'genre', 'description', 'director', 'actors', 'year', 'runtime', 'rating', 'votes', 'revenue', 'metascore']

df.columns
# Out:
# Index(['title', 'genre', 'description', 'director', 'actors', 'year',
#        'runtime', 'rating', 'votes', 'revenue', 'metascore'],
#       dtype='object')

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #2e7d32;'>✅ Actions Taken</h3>
#   <ul>
#     <li><strong>Rank</strong> column has been removed from the dataset.</li>
#     <li>Column names have been standardized.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.1. Title

# %%
df[['title']].sample(5)
# Out:
#                         title
# 11             Hidden Figures
# 238  The Grand Budapest Hotel
# 546         Don't Think Twice
# 192                 Spotlight
# 174                    Frozen

# %%
df.title.nunique()
# Out:
# 999

# %%
df.title.unique()[:10]
# Out:
# array(['Guardians of the Galaxy', 'Prometheus', 'Split', 'Sing',
#        'Suicide Squad', 'The Great Wall', 'La La Land', 'Mindhorn',
#        'The Lost City of Z', 'Passengers'], dtype=object)

# %%
df.title.value_counts()
# Out:
# title
# The Host                   2
# Guardians of the Galaxy    1
# The Hurt Locker            1
# The Daughter               1
# Pineapple Express          1
#                           ..
# The Fault in Our Stars     1
# Blended                    1
# Fast & Furious             1
# Looper                     1
# Nine Lives                 1
# Name: count, Length: 999, dtype: int64

# %%
df[df.duplicated(subset='title', keep=False)]
# Out:
#         title                     genre  \
# 239  The Host  Action,Adventure,Romance
# 632  The Host       Comedy,Drama,Horror
#
#                                            description       director  \
# 239  When an unseen enemy threatens mankind by taki...  Andrew Niccol
# 632  A monster emerges from Seoul's Han River and f...   Bong Joon Ho
#
#                                                 actors  year  runtime  rating  \
# 239  Saoirse Ronan, Max Irons, Jake Abel, Diane Kruger  2013      125     5.9
# 632  Kang-ho Song, Hee-Bong Byun, Hae-il Park, Doon...  2006      120     7.0
#
#      votes  revenue  metascore
# 239  96852    26.62       35.0
# 632  73491     2.20       85.0

# %%
df.title = df.title.str.replace(r'\s+', ' ', regex=True).str.strip()

df.title
# Out:
# 0      Guardians of the Galaxy
# 1                   Prometheus
# 2                        Split
# 3                         Sing
# 4                Suicide Squad
#                 ...
# 995       Secret in Their Eyes
# 996            Hostel: Part II
# 997     Step Up 2: The Streets
# 998               Search Party
# 999                 Nine Lives
# Name: title, Length: 1000, dtype: object

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #2e7d32;'>✅ Action Taken</h3>
#   <ul>
#     <li>Basic text cleaning has been applied to the relevant column.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.2. Genre

# %%
df[['genre']].sample(5)
# Out:
#                       genre
# 107  Action,Adventure,Drama
# 310   Biography,Drama,Sport
# 876   Comedy,Horror,Romance
# 905                   Drama
# 329     Crime,Drama,Mystery

# %%
df.genre.nunique()
# Out:
# 207

# %%
df.genre.unique()[:10]
# Out:
# array(['Action,Adventure,Sci-Fi', 'Adventure,Mystery,Sci-Fi',
#        'Horror,Thriller', 'Animation,Comedy,Family',
#        'Action,Adventure,Fantasy', 'Comedy,Drama,Music', 'Comedy',
#        'Action,Adventure,Biography', 'Adventure,Drama,Romance',
#        'Adventure,Family,Fantasy'], dtype=object)

# %%
df.genre.value_counts()
# Out:
# genre
# Action,Adventure,Sci-Fi    50
# Drama                      48
# Comedy,Drama,Romance       35
# Comedy                     32
# Drama,Romance              31
#                            ..
# Action,Comedy,Family        1
# Action,Crime,Fantasy        1
# Comedy,Mystery              1
# Adventure,Comedy,Horror     1
# Comedy,Family,Fantasy       1
# Name: count, Length: 207, dtype: int64

# %%
df.genre = df.genre.str.replace(r'\s*,\s*', ', ', regex=True).str.strip()

df.genre
# Out:
# 0       Action, Adventure, Sci-Fi
# 1      Adventure, Mystery, Sci-Fi
# 2                Horror, Thriller
# 3       Animation, Comedy, Family
# 4      Action, Adventure, Fantasy
#                   ...
# 995         Crime, Drama, Mystery
# 996                        Horror
# 997         Drama, Music, Romance
# 998             Adventure, Comedy
# 999       Comedy, Family, Fantasy
# Name: genre, Length: 1000, dtype: object

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #2e7d32;'>✅ Action Taken</h3>
#   <ul>
#     <li>Basic text cleaning has been applied to the relevant column.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.3. Description

# %%
df[['description']].sample(5)
# Out:
#                                            description
# 66   The story of the 2013 Boston Marathon bombing ...
# 579  Mr. David Marks was suspected but never tried ...
# 803  Jack Ryan, as a young covert CIA analyst, unco...
# 153  An idealistic FBI agent is enlisted by a gover...
# 389  Transported to Barsoom, a Civil War vet discov...

# %%
df.description.nunique()
# Out:
# 1000

# %%
df.description.unique()[:10]
# Out:
# array(['A group of intergalactic criminals are forced to work together to stop a fanatical warrior from taking control of the universe.',
#        'Following clues to the origin of mankind, a team finds a structure on a distant moon, but they soon realize they are not alone.',
#        'Three girls are kidnapped by a man with a diagnosed 23 distinct personalities. They must try to escape before the apparent emergence of a frightful new 24th.',
#        "In a city of humanoid animals, a hustling theater impresario's attempt to save his theater with a singing competition becomes grander than he anticipates even as its finalists' find that their lives will never be the same.",
#        'A secret government agency recruits some of the most dangerous incarcerated super-villains to form a defensive task force. Their first mission: save the world from the apocalypse.',
# ...

# %%
df.description = df.description.str.replace('"', "'", regex=False).str.replace(r'\s+', ' ', regex=True).str.strip()

df.description
# Out:
# 0      A group of intergalactic criminals are forced ...
# 1      Following clues to the origin of mankind, a te...
# 2      Three girls are kidnapped by a man with a diag...
# 3      In a city of humanoid animals, a hustling thea...
# 4      A secret government agency recruits some of th...
#                              ...
# 995    A tight-knit team of rising investigators, alo...
# 996    Three American college students studying abroa...
# 997    Romantic sparks occur between two dance studen...
# 998    A pair of friends embark on a mission to reuni...
# 999    A stuffy businessman finds himself trapped ins...
# Name: description, Length: 1000, dtype: object

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #2e7d32;'>✅ Action Taken</h3>
#   <ul>
#     <li>Basic text cleaning has been applied to the relevant column.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.4. Director

# %%
df[['director']].sample(5)
# Out:
#             director
# 479    Justin Kurzel
# 275  Joseph Kosinski
# 758    Marcus Nispel
# 636     Duncan Jones
# 860    Allen Coulter

# %%
df.director.nunique()
# Out:
# 644

# %%
df.director.unique()[:10]
# Out:
# array(['James Gunn', 'Ridley Scott', 'M. Night Shyamalan',
#        'Christophe Lourdelet', 'David Ayer', 'Yimou Zhang',
#        'Damien Chazelle', 'Sean Foley', 'James Gray', 'Morten Tyldum'],
#       dtype=object)

# %%
df.director.value_counts()
# Out:
# director
# Ridley Scott          8
# David Yates           6
# M. Night Shyamalan    6
# Paul W.S. Anderson    6
# Michael Bay           6
#                      ..
# Lee Toland Krieger    1
# Gillies MacKinnon     1
# Peter Atencio         1
# James Mangold         1
# Scot Armstrong        1
# Name: count, Length: 644, dtype: int64

# %%
df.director = df.director.str.replace(r'\s+', ' ', regex=True).str.strip()

df.director
# Out:
# 0                James Gunn
# 1              Ridley Scott
# 2        M. Night Shyamalan
# 3      Christophe Lourdelet
# 4                David Ayer
#                ...
# 995               Billy Ray
# 996                Eli Roth
# 997              Jon M. Chu
# 998          Scot Armstrong
# 999        Barry Sonnenfeld
# Name: director, Length: 1000, dtype: object

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #2e7d32;'>✅ Action Taken</h3>
#   <ul>
#     <li>Basic text cleaning has been applied to the relevant column.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.5. Actors

# %%
df[['actors']].sample(5)
# Out:
#                                                 actors
# 474  Ben Affleck, Bryan Cranston, John Goodman, Ala...
# 660  Seth Rogen, James Franco, Gary Cole, Danny McB...
# 254  Patrick Wilson, Vera Farmiga, Ron Livingston, ...
# 325  Vin Diesel, Rose Leslie, Elijah Wood, Ólafur D...
# 403  Steve Carell, Jason Segel, Russell Brand, Juli...

# %%
df.actors.nunique()
# Out:
# 996

# %%
df.actors.unique()[:10]
# Out:
# array(['Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana',
#        'Noomi Rapace, Logan Marshall-Green, Michael Fassbender, Charlize Theron',
#        'James McAvoy, Anya Taylor-Joy, Haley Lu Richardson, Jessica Sula',
#        'Matthew McConaughey,Reese Witherspoon, Seth MacFarlane, Scarlett Johansson',
#        'Will Smith, Jared Leto, Margot Robbie, Viola Davis',
#        'Matt Damon, Tian Jing, Willem Dafoe, Andy Lau',
#        'Ryan Gosling, Emma Stone, Rosemarie DeWitt, J.K. Simmons',
#        'Essie Davis, Andrea Riseborough, Julian Barratt,Kenneth Branagh',
#        'Charlie Hunnam, Robert Pattinson, Sienna Miller, Tom Holland',
#        'Jennifer Lawrence, Chris Pratt, Michael Sheen,Laurence Fishburne'],
#       dtype=object)

# %%
df.actors.value_counts()
# Out:
# actors
# Jennifer Lawrence, Josh Hutcherson, Liam Hemsworth, Woody Harrelson    2
# Daniel Radcliffe, Emma Watson, Rupert Grint, Michael Gambon            2
# Shia LaBeouf, Megan Fox, Josh Duhamel, Tyrese Gibson                   2
# Gerard Butler, Aaron Eckhart, Morgan Freeman,Angela Bassett            2
# Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana                   1
#                                                                       ..
# Alexi Pappas, Chase Offerle, Rachel Dratch, Andy Buckley               1
# Shailene Woodley, Ansel Elgort, Nat Wolff, Laura Dern                  1
# Adam Sandler, Drew Barrymore, Wendi McLendon-Covey, Kevin Nealon       1
# Vin Diesel, Paul Walker, Michelle Rodriguez, Jordana Brewster          1
# Kevin Spacey, Jennifer Garner, Robbie Amell,Cheryl Hines               1
# Name: count, Length: 996, dtype: int64

# %%
df[df.duplicated(subset='actors', keep=False)]
# Out:
#                                             title                       genre  \
# 114  Harry Potter and the Deathly Hallows: Part 2   Adventure, Drama, Fantasy
# 212                                  Transformers   Action, Adventure, Sci-Fi
# 408         The Hunger Games: Mockingjay - Part 2   Action, Adventure, Sci-Fi
# 424                             London Has Fallen        Action, Crime, Drama
# 453                            Olympus Has Fallen            Action, Thriller
# 473        Harry Potter and the Half-Blood Prince  Adventure, Family, Fantasy
# 680         The Hunger Games: Mockingjay - Part 1   Action, Adventure, Sci-Fi
# 710           Transformers: Revenge of the Fallen   Action, Adventure, Sci-Fi
#
#                                            description          director  \
# 114  Harry, Ron and Hermione search for Voldemort's...       David Yates
# 212  An ancient struggle between two Cybertronian r...       Michael Bay
# ...

# %%
df.actors = df.actors.str.replace(r'\s*,\s*', ', ', regex=True).str.strip()

df.actors
# Out:
# 0      Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1      Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2      James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3      Matthew McConaughey, Reese Witherspoon, Seth M...
# 4      Will Smith, Jared Leto, Margot Robbie, Viola D...
#                              ...
# 995    Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# 996    Lauren German, Heather Matarazzo, Bijou Philli...
# 997    Robert Hoffman, Briana Evigan, Cassie Ventura,...
# 998    Adam Pally, T.J. Miller, Thomas Middleditch, S...
# 999    Kevin Spacey, Jennifer Garner, Robbie Amell, C...
# Name: actors, Length: 1000, dtype: object

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #2e7d32;'>✅ Action Taken</h3>
#   <ul>
#     <li>Basic text cleaning has been applied to the relevant column.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.6. Year

# %%
df[['year']].sample(5)
# Out:
#      year
# 621  2012
# 230  2006
# 598  2009
# 667  2015
# 386  2015

# %%
df.year.min()
# Out:
# 2006

# %%
df.year.max()
# Out:
# 2016

# %%
df.year.describe()
# Out:
# count    1000.000000
# mean     2012.783000
# std         3.205962
# min      2006.000000
# 25%      2010.000000
# 50%      2014.000000
# 75%      2016.000000
# max      2016.000000
# Name: year, dtype: float64

# %% [markdown]
# ## 5.7. Runtime

# %%
df[['runtime']].sample(5)
# Out:
#      runtime
# 473      153
# 218      100
# 842      135
# 104      116
# 999       87

# %%
df.runtime.min()
# Out:
# 66

# %%
df.runtime.max()
# Out:
# 191

# %%
df.runtime.describe()
# Out:
# count    1000.000000
# mean      113.172000
# std        18.810908
# min        66.000000
# 25%       100.000000
# 50%       111.000000
# 75%       123.000000
# max       191.000000
# Name: runtime, dtype: float64

# %% [markdown]
# ## 5.8. Rating

# %%
df[['rating']].sample(5)
# Out:
#      rating
# 304     6.4
# 206     7.5
# 675     7.2
# 968     3.5
# 761     7.3

# %%
df.rating.min()
# Out:
# 1.9

# %%
df.rating.max()
# Out:
# 9.0

# %%
df.rating.describe()
# Out:
# count    1000.000000
# mean        6.723200
# std         0.945429
# min         1.900000
# 25%         6.200000
# 50%         6.800000
# 75%         7.400000
# max         9.000000
# Name: rating, dtype: float64

# %% [markdown]
# ## 5.9. Votes

# %%
df[['votes']].sample(5)
# Out:
#       votes
# 871   59512
# 373  312495
# 855    9993
# 122   53183
# 858  136642

# %%
df.votes.min()
# Out:
# 61

# %%
df.votes.max()
# Out:
# 1791916

# %%
df.votes.describe()
# Out:
# count    1.000000e+03
# mean     1.698083e+05
# std      1.887626e+05
# min      6.100000e+01
# 25%      3.630900e+04
# 50%      1.107990e+05
# 75%      2.399098e+05
# max      1.791916e+06
# Name: votes, dtype: float64

# %% [markdown]
# ## 5.10. Revenue

# %%
df[['revenue']].sample(5)
# Out:
#      revenue
# 918     2.21
# 577   172.05
# 723    20.75
# 423   106.37
# 41     27.85

# %%
df.revenue.isna().sum()
# Out:
# np.int64(128)

# %%
df.revenue.min()
# Out:
# 0.0

# %%
df.revenue.max()
# Out:
# 936.63

# %%
df.revenue.describe()
# Out:
# count    872.000000
# mean      82.956376
# std      103.253540
# min        0.000000
# 25%       13.270000
# 50%       47.985000
# 75%      113.715000
# max      936.630000
# Name: revenue, dtype: float64

# %%
df[df.revenue == 0]
# Out:
#                 title                   genre  \
# 231  A Kind of Murder  Crime, Drama, Thriller
#
#                                            description      director  \
# 231  In 1960s New York, Walter Stackhouse is a succ...  Andy Goddard
#
#                                                 actors  year  runtime  rating  \
# 231  Patrick Wilson, Jessica Biel, Haley Bennett, V...  2016       95     5.2
#
#      votes  revenue  metascore
# 231   3305      0.0       50.0

# %%
df.revenue = df.revenue.replace(0, np.nan)

df.revenue
# Out:
# 0      333.13
# 1      126.46
# 2      138.12
# 3      270.32
# 4      325.02
#         ...
# 995       NaN
# 996     17.54
# 997     58.01
# 998       NaN
# 999     19.64
# Name: revenue, Length: 1000, dtype: float64

# %%
df.revenue.isna().sum()
# Out:
# np.int64(129)

# %%
df.revenue.describe()
# Out:
# count    871.000000
# mean      83.051619
# std      103.274531
# min        0.010000
# 25%       13.350000
# 50%       48.020000
# 75%      113.720000
# max      936.630000
# Name: revenue, dtype: float64

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #2e7d32;'>✅ Action Taken</h3>
#   <ul>
#     <li>The value 0, which may indicate a data error in the relevant column, has been reclassified as missing data.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.11. Metascore

# %%
df[['metascore']].sample(5)
# Out:
#      metascore
# 808       65.0
# 8         78.0
# 404       29.0
# 331       72.0
# 32        52.0

# %%
df.metascore.isna().sum()
# Out:
# np.int64(64)

# %%
df.metascore.min()
# Out:
# 11.0

# %%
df.metascore.max()
# Out:
# 100.0

# %%
df.metascore.describe()
# Out:
# count    936.000000
# mean      58.985043
# std       17.194757
# min       11.000000
# 25%       47.000000
# 50%       59.500000
# 75%       72.000000
# max      100.000000
# Name: metascore, dtype: float64

# %% [markdown]
# # 6. Analiz ve Görselleştirme

# %%
df.votes.describe()
# Out:
# count    1.000000e+03
# mean     1.698083e+05
# std      1.887626e+05
# min      6.100000e+01
# 25%      3.630900e+04
# 50%      1.107990e+05
# 75%      2.399098e+05
# max      1.791916e+06
# Name: votes, dtype: float64

# %%
top100 = df[df.votes >= 240000].sort_values('rating', ascending=False)[:100].reset_index(drop=True)

top100
# Out:
#                            title                      genre  \
# 0                The Dark Knight       Action, Crime, Drama
# 1                      Inception  Action, Adventure, Sci-Fi
# 2                   Interstellar   Adventure, Drama, Sci-Fi
# 3               The Intouchables   Biography, Comedy, Drama
# 4                   The Departed     Crime, Drama, Thriller
# ..                           ...                        ...
# 95                X: First Class  Action, Adventure, Sci-Fi
# 96                 The Big Short   Biography, Comedy, Drama
# 97  Kingsman: The Secret Service  Action, Adventure, Comedy
# 98             Midnight in Paris   Comedy, Fantasy, Romance
# 99      The Theory of Everything  Biography, Drama, Romance
#
#                                           description           director  \
# 0   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 1   A thief, who steals corporate secrets through ...  Christopher Nolan
# ...

# %%
sns.histplot(top100.rating, bins=15, kde=True)

plt.title('Rating Distribution of the Top 100 Movies')
plt.xlabel('Rating')
plt.ylabel('Frequency')

plt.show()

# %%
sns.scatterplot(x=top100.votes, y=top100.rating)

plt.title('Relationship Between Votes and Rating for the Top 100 Movies')
plt.xlabel('Votes')
plt.ylabel('Rating')

plt.show()

# %%
year_counts = top100.year.value_counts().sort_index()

sns.lineplot(x=year_counts.index, y=year_counts.values)

plt.title('Distribution of the Top 100 Movies by Year')
plt.xlabel('Year')
plt.ylabel('Number of Movies')

plt.show()

# %%
top10_genre = top100.genre.value_counts().head(10)

plt.pie(top10_genre.values, labels=top10_genre.index, autopct='%1.1f%%')

plt.title('Distribution of the Top 10 Genres')

plt.show()

# %%
from wordcloud import WordCloud

text = ' '.join(df.actors)

wordcloud = WordCloud(width=1600, height=800, background_color='white', colormap='viridis', max_words=150, max_font_size=200, random_state=42).generate(text)

plt.imshow(wordcloud, interpolation='bilinear')

plt.axis('off')

plt.show()

# %% [markdown]
# <div style='background-color: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #2e7d32;'>📊 Results</h3>
#   <ul>
#     <li>Ratings of movies in the elite segment are concentrated within a narrow range, indicating an overall high rating level.</li>
#     <li>No strong linear relationship was observed between votes and rating, suggesting that higher popularity does not always imply higher ratings.</li>
#     <li>The distribution of movies by year shows periods of concentration, with the elite segment clustering particularly in certain years.</li>
#     <li>Genre distribution indicates that action, adventure, and drama combinations dominate the elite segment.</li>
#     <li>Actor analysis shows that certain actors repeatedly stand out in the elite segment, indicating the presence of a star power effect.</li>
#   </ul>
# </div>
